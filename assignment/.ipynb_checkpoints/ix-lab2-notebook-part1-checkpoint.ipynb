# %% [markdown]
# # Networks: structure, evolution & processes
# **Internet Analytics - Lab 2**
#
# ---
#
# **Group:** *Your group letter.*
#
# **Names:**
#
# * *Name 1*
# * *Name 2*
# * *Name 3*
#
# ---
#
# #### Instructions
#
# *This is a template for part 1 of the lab. Clearly write your answers, comments and interpretations in Markodown cells. Don't forget that you can add $\LaTeX$ equations in these cells. Feel free to add or remove any cell.*
#
# *Please properly comment your code. Code readability will be considered for grading. To avoid long cells of codes in the notebook, you can also embed long python functions and classes in a separate module. Don’t forget to hand in your module if that is the case. In multiple exercises, you are required to come up with your own method to solve various problems. Be creative and clearly motivate and explain your methods. Creativity and clarity will be considered for grading.*

# %% [markdown]
# ---
#
# ## 2.1 Exploration of real networks
#
# #### Exercise 2.1

# %%
import pandas as pd
print("ewa")
network1 = pd.read_csv('../data/network1.csv', comment = '#', header = None)
network1.columns = ['fromNode', 'toNode']
network1.head()
print("ewa")
# Out:
# ewa
# ewa

# %% [markdown]
# #### Exercise 2.2:  Node degree distribution

# %%
import networkx as nx
G = nx.Graph()
G = nx.from_pandas_edgelist(network1, 'fromNode', 'toNode')

# %%
num_edges = len(network1.index)
print(num_edges)
# Out:
# 18584

# %%
num_edges = G.number_of_edges()
num_nodes = G.number_of_nodes()
print(num_edges)
print(num_nodes)
# Out:
# 18584
# 13033

# %%
import matplotlib.pyplot as plt
import collections
import numpy as np

degree_sequence = sorted((val for (node, val) in G.degree()), reverse=False)
degreeCount = collections.Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

fig, ax = plt.subplots(ncols=1, figsize=(16, 4))

plt.plot(np.log(deg), np.log(cnt), color='crimson', marker='.', zorder=2)
#plt.axis([-10, 1500, 0, 8300])
#ax.bar(deg, cnt, width=15, zorder=1)
ax.set_ylabel('degree frequency')
ax.set_xlabel('degree')
# Out:
# Text(0.5, 0, 'degree')

# %% [markdown]
# 1. What kind of plot do you think is useful for this task?
# **It could be a histogram, scatter or bar graph. It should show how frequent degrees appears in the dataset.**

# %% [markdown]
# 2. Can you list some of the properties of the degree distribution?
# **An important graph property is the degree distribution function P (k), that describes the probability to find a node with k edges**

# %% [markdown]
# 3. Is it close to a well-known probability distribution? If so, provide an estimation of its
# parameter(s)?
# **Probably it looks a little bit like a power-law distribution**
# **A scale-free graph is instead characterized by a power-law degree distribution P (k) = Ak −γ , usually with 2 < γ < 3. A power-law distribution appears as a straight line in a double-logarithmic plot. In a scale-free graph, low degree nodes are the most frequent ones, but there are also a few highly connected nodes, usually called hubs.**

# %%
#draw the graph
#nx.draw(G)

# %% [markdown]
# #### Exercise 2.3: Giant component

# %%
print(nx.number_connected_components(G))
# Out:
# 192

# %%
import numpy as np
np_cnt = np.array(cnt)
np_deg = np.array(deg)
c = sum(np_cnt * np_deg) / len(G)

print(c)
if c > 1:
    Gcc = sorted(nx.connected_components(G), key=len, reverse=True)
    G0 = G.subgraph(Gcc[0])
    print(G0)
else:
    print("There is no giant component")
# Out:
# 2.8518376429064682
# Graph with 12576 nodes and 18317 edges

# %% [markdown]
# #### Exercise 2.4: Short paths & Small-worlds

# %%
#average length of connection between every two nodes in graph
avg_length = []
for C in (G.subgraph(c).copy() for c in nx.connected_components(G)):
    avg_length.append(nx.average_shortest_path_length(C))
print(sum(avg_length) / len(avg_length))
# Out:
# 1.1072818079387936

# %%
shortest_paths = list(nx.shortest_path_length(G))
print(shortest_paths[0])
# Out:
# (0, {0: 0, 11932: 1, 3585: 2, 7938: 2, 1284: 2, 1285: 2, 4615: 2, 3849: 2, 5129: 2, 907: 2, 6155: 2, 1680: 2, 8720: 2, 790: 2, 10648: 2, 6811: 2, 4381: 2, 1695: 2, 5548: 2, 12460: 2, 5295: 2, 5041: 2, 690: 2, 4918: 2, 4279: 2, 11702: 2, 7611: 2, 7235: 2, 1094: 2, 2374: 2, 584: 2, 4297: 2, 4681: 2, 1611: 2, 7883: 2, 3405: 2, 11642: 2, 2897: 2, 10323: 2, 6102: 2, 4958: 2, 99: 2, 7396: 2, 8569: 2, 4728: 2, 8817: 2, 884: 2, 10100: 2, 9334: 2, 9207: 2, 1400: 2, 7161: 2, 3066: 2, 9974: 2, 5826: 3, 9255: 3, 4651: 3, 461: 3, 4941: 3, 7472: 3, 10290: 3, 5939: 3, 10003: 3, 2714: 3, 12290: 4, 12294: 4, 8199: 4, 12: 4, 2060: 4, 12300: 4, 12303: 4, 8208: 4, 8210: 4, 6163: 4, 4116: 4, 8213: 4, 6167: 4, 12311: 4, 12315: 4, 10276: 4, 12325: 4, 2086: 4, 2089: 4, 10282: 4, 43: 4, 6189: 4, 2099: 4, 52: 4, 8244: 4, 4153: 4, 6201: 4, 12348: 4, 6205: 4, 8254: 4, 8255: 4, 6208: 4, 2115: 4, 8261: 4, 8263: 4, 10314: 4, 6219: 4, 10318: 4, 8270: 4, 4174: 4, 8276: 4, 12372: 4, 2136: 4, 8281: 4, 10329: 4, 12379: 4, 8284: 4, 8287: 4, 101: 4, 8294: 4, 2153: 4, 12396: 4, 12401: 4, 116: 4, 4213: 4, 6263: 4, 4218: 4, 10362: 4, 8315: 4, 6272: 4, 130: 4, 2179: 4, 8323: 4, 2184: 4, 12424: 4, 2190: 4, 2191: 4, 2192: 4, 4240: 4, 2199: 4, 4247: 4, 8345: 4, 10391: 4, 10393: 4, 4252: 4, 6303: 4, 10399: 4, 12451: 4, 2213: 4, 167: 4, 12462: 4, 10417: 4, 10421: 4, 2229: 4, 4277: 4, 12470: 4, 4285: 4, 8381: 4, 194: 4, 2249: 4, 8395: 4, 6352: 4, 10455: 4, 216: 4, 6361: 4, 8412: 4, 2271: 4, 12515: 4, 10470: 4, 10471: 4, 2283: 4, 6379: 4, 241: 4, 2290: 4, 4337: 4, 246: 4, 4342: 4, 6391: 4, 12543: 4, 6401: 4, 8450: 4, 257: 4, 4356: 4, 4354: 4, 263: 4, 4368: 4, 4374: 4, 280: 4, 2331: 4, 10524: 4, 2333: 4, 6430: 4, 10525: 4, 288: 4, 2338: 4, 12581: 4, 6449: 4, 6450: 4, 8500: 4, 8508: 4, 12608: 4, 2370: 4, 10563: 4, 4423: 4, 331: 4, 2379: 4, 10573: 4, 12621: 4, 4429: 4, 2384: 4, 4427: 4, 6477: 4, 2392: 4, 12635: 4, 8540: 4, 354: 4, 8551: 4, 12648: 4, 10603: 4, 2412: 4, 2413: 4, 8562: 4, 6515: 4, 8566: 4, 10618: 4, 6528: 4, 4492: 4, 8588: 4, 2446: 4, 8590: 4, 10636: 4, 2449: 4, 12694: 4, 6553: 4, 12697: 4, 12699: 4, 413: 4, 8611: 4, 421: 4, 4517: 4, 2473: 4, 427: 4, 8619: 4, 2478: 4, 8626: 4, 10675: 4, 6588: 4, 10685: 4, 12737: 4, 12741: 4, 4550: 4, 8647: 4, 4551: 4, 459: 4, 10700: 4, 10702: 4, 10699: 4, 4571: 4, 10716: 4, 6624: 4, 8674: 4, 488: 4, 8682: 4, 6634: 4, 2540: 4, 10740: 4, 8696: 4, 10746: 4, 12797: 4, 8704: 4, 6656: 4, 12808: 4, 4617: 4, 8714: 4, 8715: 4, 524: 4, 12813: 4, 2575: 4, 6672: 4, 12819: 4, 6680: 4, 538: 4, 10783: 4, 6698: 4, 2606: 4, 12847: 4, 562: 4, 568: 4, 572: 4, 6717: 4, 574: 4, 579: 4, 12868: 4, 2630: 4, 586: 4, 10827: 4, 6732: 4, 10828: 4, 591: 4, 599: 4, 10841: 4, 8794: 4, 6753: 4, 2658: 4, 8807: 4, 12904: 4, 617: 4, 6767: 4, 2678: 4, 10872: 4, 12921: 4, 634: 4, 2682: 4, 8828: 4, 10877: 4, 10874: 4, 6798: 4, 10902: 4, 2711: 4, 12952: 4, 672: 4, 12961: 4, 674: 4, 4771: 4, 12963: 4, 4773: 4, 2726: 4, 8870: 4, 10920: 4, 12964: 4, 2734: 4, 687: 4, 12976: 4, 10928: 4, 2738: 4, 8884: 4, 2740: 4, 12983: 4, 8890: 4, 4798: 4, 10943: 4, 8895: 4, 2754: 4, 2757: 4, 12999: 4, 4807: 4, 6857: 4, 13003: 4, 4818: 4, 723: 4, 4820: 4, 6868: 4, 10969: 4, 2779: 4, 6876: 4, 2789: 4, 10982: 4, 8939: 4, 10988: 4, 6897: 4, 6907: 4, 2812: 4, 8961: 4, 2825: 4, 778: 4, 8970: 4, 8976: 4, 6932: 4, 8982: 4, 6936: 4, 4899: 4, 6951: 4, 6952: 4, 817: 4, 6962: 4, 9010: 4, 821: 4, 823: 4, 6969: 4, 6970: 4, 9019: 4, 6972: 4, 829: 4, 11069: 4, 9023: 4, 11067: 4, 4930: 4, 6982: 4, 4936: 4, 4937: 4, 2890: 4, 843: 4, 11087: 4, 852: 4, 2905: 4, 864: 4, 7008: 4, 7012: 4, 2918: 4, 875: 4, 11116: 4, 11126: 4, 2940: 4, 9091: 4, 7046: 4, 2956: 4, 11155: 4, 11156: 4, 2963: 4, 7060: 4, 7065: 4, 922: 4, 7066: 4, 2981: 4, 2983: 4, 7083: 4, 2988: 4, 11180: 4, 5037: 4, 5039: 4, 11194: 4, 5052: 4, 956: 4, 3008: 4, 9155: 4, 11206: 4, 11215: 4, 11217: 4, 978: 4, 5075: 4, 3030: 4, 9176: 4, 3033: 4, 5082: 4, 9186: 4, 3044: 4, 5094: 4, 1008: 4, 5105: 4, 1010: 4, 9203: 4, 7159: 4, 7164: 4, 9216: 4, 1026: 4,  ...

# %%
paths_list = []
for node in shortest_paths:
    temp = [value for value in node[1].values()]
    paths_list.extend(temp)
print(paths_list)

#degree_sequence = sorted((val for (node, val) in G.degree()), reverse=False)
degreeCount = collections.Counter(paths_list)
deg, cnt = zip(*degreeCount.items())
#print(deg, cnt)

fig, ax = plt.subplots(ncols=1, figsize=(16, 4))

#ax.scatter(deg , cnt, color='crimson', marker='.', zorder=2)
#plt.axis([-10, 100, 0, 8000])
#ax.bar(deg, cnt, width=15, zorder=1)
ax.bar(deg, cnt)
ax.set_ylabel('count')
ax.set_xlabel('shortest path length')
plt.show()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
def reachable_r(r):
    how_many = 0
    for node in paths_list:
        if node <= r:
            how_many += 1
    print(how_many)
    print(len(paths_list))
    return (how_many / len(paths_list)) * 100

# %%
r = 2
reachable_r(r)
# Out:
# 5469553
# 158157161
# 3.458302466620528

# %%
r = 6
reachable_r(r)
# Out:
# 154511017
# 158157161
# 97.69460707504733

# %%
r = 10
reachable_r(r)
# Out:
# 158156361
# 158157161
# 99.99949417402605

# %% [markdown]
# #### Exercise 2.5: Network comparison

# %%
network2 = pd.read_csv('../data/network2.csv', comment = '#', header = None)
network2.columns = ['fromNode', 'toNode']
network2.head()

# %% [markdown]
# **Properties of previous network**

# %%
#create the graph of second network
G2 = nx.Graph()
G2 = nx.from_pandas_edgelist(network2, 'fromNode', 'toNode')

# %%
#calc num of edges and nodes in the graph
num_edges = G2.number_of_edges()
num_nodes = G2.number_of_nodes()
print(num_edges)
print(num_nodes)

# %%
# distribution of degrees in the network
degree_sequence = sorted((val for (node, val) in G2.degree()), reverse=False)
degreeCount = collections.Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())
print(deg, cnt)

fig, ax = plt.subplots(ncols=1, figsize=(16, 4))

ax.scatter(deg, cnt, color='crimson', marker='.', zorder=2)
ax.plot(deg, cnt, color='green')
plt.axis([-10, 20, 0, 14000])
ax.bar(deg, cnt, width=15, zorder=1)
ax.set_ylabel('degree frequency')
ax.set_xlabel('degree')

# %%
#draw the graph
#nx.draw(G2)

# %%
#number of connected components in graph
print(nx.number_connected_components(G2))
# Out:
# 5

# %%
#find giant component and show its properties if it exists
np_cnt = np.array(cnt)
np_deg = np.array(deg)
c = sum(np_cnt * np_deg) / len(G2)

print(c)
if c > 1:
    Gcc = sorted(nx.connected_components(G), key=len, reverse=True)
    G0 = G.subgraph(Gcc[0])
    print(G0)
else:
    print("There is no giant component")
# Out:
# 3.2790294627383014
# Graph with 12576 nodes and 18317 edges

# %%
#analyse of short paths and in this context the small-world

# %%
#average length of connection between every two nodes in graph
avg_length = []
for C in (G2.subgraph(c).copy() for c in nx.connected_components(G2)):
    avg_length.append(nx.average_shortest_path_length(C))
print(sum(avg_length) / len(avg_length))
# Out:
# 21.66007803486037

# %% [markdown]
# #### Exercise 2.6: Network identification

# %% [markdown]
# # Networks: structure, evolution & processes
# **Internet Analytics - Lab 2**
#
# ---
#
# **Group:** *Your group letter.*
#
# **Names:**
#
# * *Name 1*
# * *Name 2*
# * *Name 3*
#
# ---
#
# #### Instructions
#
# *This is a template for part 3 of the lab. Clearly write your answers, comments and interpretations in Markodown cells. Don't forget that you can add $\LaTeX$ equations in these cells. Feel free to add or remove any cell.*
#
# *Please properly comment your code. Code readability will be considered for grading. To avoid long cells of codes in the notebook, you can also embed long python functions and classes in a separate module. Don’t forget to hand in your module if that is the case. In multiple exercises, you are required to come up with your own method to solve various problems. Be creative and clearly motivate and explain your methods. Creativity and clarity will be considered for grading.*

# %% [markdown]
# ---
#
# ## 2.3 Epdemics
#
# #### Exercise 2.9: Simulate an epidemic outbreak

# %%
#Imports
import epidemics_helper
import json
import networkx as nx
from networkx.readwrite import json_graph
import numpy as np
from enum import Enum
import collections
import matplotlib.pyplot as plt

# %%
#Load data
def read_json_file(filename):
    with open(filename) as f:
        js_graph = json.load(f)
    return json_graph.node_link_graph(js_graph)

# %%
DATA_DIR = './../data/'

G = read_json_file(f'{DATA_DIR}nyc_augmented_network.json')

# %% [markdown]
# 1. Lauch outbreak

# %%
#Start simulation and lauch outbreak
beta = 10.0
gamma = 0.1

source = 23654
max_time = 100.0

def simulate_outbreak(G, beta, gamma, source, max_time):
    sir = epidemics_helper.SimulationSIR(G, beta=beta, gamma=gamma)
    sir.launch_epidemic(source=source, max_time=max_time)
    return sir

# %%
sir = simulate_outbreak(G, beta, gamma, source, max_time)
# Out:
# Epidemic stopped after 101.72 days | 101.72 days elapsed | 0.1% susceptible, 0.0% infected, 99.9% recovered

# %% [markdown]
# 2. Plot the evolution of the epidemic over time

# %%
class State(Enum):
    susceptible = 0
    infectious = 1
    recovered = 2

def get_node_states(G, day):
    node_states = [sir.get_node_status(node, day) for node in sir.G.nodes()]
    return node_states

def get_all_node_states(G):
    days = np.arange(int(max_time))
    nodes = []
    for i in days:
        node_states = get_node_states(G, i)
        collection = collections.Counter(node_states)
        collection = dict(sorted(collection.items(),key = lambda i: i[0], reverse=False))
        nodes.append(collection)
    return days, nodes
        

days, nodes = get_all_node_states(G)

# %%
width = 0.5
  
def get_state_percentage(sir, state):
    return np.array([node.get(state) if node.get(state) is not None else 0 for node in nodes]) / len(sir.G.nodes())

susceptible_vals = get_state_percentage(sir, 0)
bar1 = plt.bar(days, susceptible_vals, width, color = 'g')
  
infectious_vals = get_state_percentage(sir, 1)
bar2 = plt.bar(days, infectious_vals, width, color='r')
  
recovered_vals =  get_state_percentage(sir, 2)
bar3 = plt.bar(days, recovered_vals, width, color = 'b')

plt.xlabel("Days")
plt.ylabel('States')
plt.title("Outbreak data")
  
plt.xticks(days[::10] + 0.25, days[::10])
plt.legend( (bar1, bar2, bar3), ('susceptible', 'infectious', 'recovered') )
plt.show()

# %% [markdown]
# 3. a) How long until 60% of the population is infected (at the same time)?

# %%
np.argmax(infectious_vals >= 0.6)
# Out:
# 8

# %% [markdown]
# 3. b)  How long until 60% of the population is recovered (at the same time)?

# %%
np.argmax(recovered_vals >= 0.6)
# Out:
# 15

# %% [markdown]
# 4. Visualize the graph

# %%
#pos0 = {city:(long, lat) for (city, (lat,long)) in nx.get_node_attributes(G, 'coordinates').items() if node_states[city] == 0}
#selected_nodes = [n for n,v in G.nodes(data=True) if node_states[n] == 0]
#H = G.subgraph(selected_nodes)
#nx.draw(H, pos0, with_labels=False, node_size=1)

#pos1 = {city:(long, lat) for (city, (lat,long)) in nx.get_node_attributes(G, 'coordinates').items() if node_states[city] == 1}
#selected_nodes = [n for n,v in G.nodes(data=True) if node_states[n] == 1]
#H1 = G.subgraph(selected_nodes)
#nx.draw(H1, pos1, with_labels=False, node_size=1, node_color=color_map)

def get_color_map(node_states):
    color_map = []
    for node in G:
        if node_states[node] == 0:
            color_map.append('green')
        elif node_states[node] == 1: 
            color_map.append('red')
        else:
            color_map.append('blue')
    return color_map

def draw_network(G, color_map):
    pos = {city:(long, lat) for (city, (lat,long)) in nx.get_node_attributes(G, 'coordinates').items()}
    nx.draw(G, pos, with_labels=False, node_size=1, node_color=color_map)

# %% [markdown]
# 4. a) How does the graph look like on day 1?

# %%
#day = 1
day = 1
node_states = get_node_states(G, day)
color_map = get_color_map(node_states)
draw_network(G, color_map)

# %% [markdown]
# 4. b) How does the graph look like on day 3?

# %%
#day = 3
day = 3
node_states = get_node_states(G, day)
color_map = get_color_map(node_states)
draw_network(G, color_map)

# %% [markdown]
# 4. c) How does the graph look like on day 30?

# %%
#day = 30
day = 30
node_states = get_node_states(G, day)
color_map = get_color_map(node_states)
draw_network(G, color_map)

# %% [markdown]
# ---
#
# ### 2.3.1 Stop the apocalypse!
#
# #### Exercise 2.10: Strategy 1

# %%
from random import sample, choice
edges_budget = 1000

G = read_json_file(f'{DATA_DIR}nyc_augmented_network.json')

def remove_edges(G, edges_budget):
    random_edges = sample(G.edges(), edges_budget)
    G.remove_edges_from(random_edges)

# %%
def get_outbrak_stats(G, day):
    node_states = get_node_states(G, day)
    collection = collections.Counter(node_states)
    collection = dict(sorted(collection.items(),key = lambda i: i[0], reverse=False))
    return collection

# %%
max_iter = 10
day = 30

def get_avg_stats(max_iter, day, edges_budget, remove_edge_mode=True):
    susceptible = []
    infectious = []
    recovered = []

    G = read_json_file(f'{DATA_DIR}nyc_augmented_network.json')
    source = choice(range(len(G.nodes())))
    if remove_edge_mode:
        remove_edges(G, edges_budget)

    for i in range(max_iter):
        sir = simulate_outbreak(G, beta, gamma, source, day)

        susceptible.append(np.sum(sir.status==0))
        infectious.append(np.sum(sir.status==1))
        recovered.append(np.sum(sir.status==2))
    return np.mean(susceptible), np.mean(infectious), np.mean(recovered)

# %%
# without removing edges:
edges_budget = 1000
get_avg_stats(max_iter, day, edges_budget, remove_edge_mode=True)
# Out:
# Epidemic spreading... 1.81 days elapsed | 83.7% susceptible, 15.3% infected, 1.0% recovered
# C:\Users\ewa.miazga\AppData\Local\Temp\ipykernel_20728\3983053099.py:7: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   random_edges = sample(G.edges(), edges_budget)
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 0.7% susceptible, 9.1% infected, 90.2% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 0.6% susceptible, 9.2% infected, 90.2% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 0.6% susceptible, 9.2% infected, 90.2% recovered
# Epidemic stopped after 30.01 days | 30.01 days elapsed | 0.6% susceptible, 9.5% infected, 89.9% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 0.6% susceptible, 9.7% infected, 89.6% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 0.7% susceptible, 9.2% infected, 90.1% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 0.7% susceptible, 9.8% infected, 89.5% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 0.6% susceptible, 9.3% infected, 90.1% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 0.7% susceptible, 9.8% infected, 89.5% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 0.7% susceptible, 9.3% infected, 90.1% recovered
# (170.7, 2492.0, 23818.3)

# %%
# edges_budget = 1000
edges_budget = 1000
get_avg_stats(max_iter, day, edges_budget)
# Out:
# Epidemic spreading... 2.21 days elapsed | 82.2% susceptible, 16.5% infected, 1.3% recovered
# C:\Users\ewa.miazga\AppData\Local\Temp\ipykernel_20728\3983053099.py:7: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   random_edges = sample(G.edges(), edges_budget)
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 0.6% susceptible, 9.3% infected, 90.1% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 0.6% susceptible, 9.2% infected, 90.2% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 0.6% susceptible, 9.3% infected, 90.1% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 20.3% susceptible, 6.5% infected, 73.2% recovered
# Epidemic stopped after 30.01 days | 30.01 days elapsed | 0.7% susceptible, 9.3% infected, 90.1% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 0.5% susceptible, 9.1% infected, 90.4% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 0.5% susceptible, 9.3% infected, 90.2% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 0.5% susceptible, 9.3% infected, 90.2% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 0.5% susceptible, 9.4% infected, 90.1% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 0.5% susceptible, 9.2% infected, 90.3% recovered
# (668.2, 2380.6, 23432.2)

# %%
# edges_budget = 10000
edges_budget = 10000
get_avg_stats(max_iter, day, edges_budget)
# Out:
# Epidemic spreading... 10.40 days elapsed | 75.1% susceptible, 15.0% infected, 10.0% recovered
# C:\Users\ewa.miazga\AppData\Local\Temp\ipykernel_20728\3983053099.py:7: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   random_edges = sample(G.edges(), edges_budget)
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 10.8% susceptible, 23.7% infected, 65.5% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 13.7% susceptible, 23.5% infected, 62.8% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 11.5% susceptible, 21.9% infected, 66.6% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 8.8% susceptible, 22.2% infected, 69.0% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 9.5% susceptible, 24.1% infected, 66.4% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 9.4% susceptible, 21.3% infected, 69.3% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 10.5% susceptible, 23.5% infected, 65.9% recovered
# Epidemic stopped after 30.01 days | 30.01 days elapsed | 9.4% susceptible, 21.8% infected, 68.8% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 8.7% susceptible, 23.9% infected, 67.4% recovered
# Epidemic stopped after 30.00 days | 30.00 days elapsed | 10.6% susceptible, 28.2% infected, 61.1% recovered
# (2726.7, 6199.6, 17554.7)

# %% [markdown]
# This strategy is not effective.

# %% [markdown]
# #### Exercise 2.11: Strategy 2

# %%
paths = nx.all_pairs_shortest_path(sir.G)
print(path[0])
# Out:
# <generator object all_pairs_shortest_path at 0x000001C830CDC200>
